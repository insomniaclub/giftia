# %%
from langchain.llms.llamacpp import LlamaCpp
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain.prompts import PromptTemplate

# Callbacks support token-wise streaming
callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])

# Metal set to 1 is enough.
n_gpu_layers = 1
# Should be between 1 and n_ctx, consider the amount of RAM of your Apple Silicon Chip.
n_batch = 512
# Make sure the model path is correct for your system!
llm = LlamaCpp(
    model_path="/Users/gensliu/.cache/huggingface/hub/models--TheBloke--Yi-34B-Chat-GGUF/snapshots/ee827f906e733381ab65c650dcfdd2caf6de8762/yi-34b-chat.Q4_K_M.gguf",
    n_gpu_layers=n_gpu_layers,
    n_batch=n_batch,
    f16_kv=True,  # MUST set to True, otherwise you will run into problem after a couple of calls
    stop=["<|im_end|>"],
    max_tokens=8192,
    # callback_manager=callback_manager,
    # verbose=True,  # Verbose is required to pass to the callback manager
)

prompt = PromptTemplate(template="""\
<|im_start|>user
{usrmsg}<|im_end|>
<|im_start|>assistant
""", input_variables=["usrmsg"])

while True:
    in_txt = input(">>> ")
    print("<<< ", end="", flush=True)
    data = prompt.format(usrmsg=in_txt)
    for chunk in llm.stream(input=data):
        print(chunk, end="", flush=True)
    print()

# %%
from llama_cpp import Llama

Yi_34B_Chat_GGUF = '/Users/gensliu/.cache/huggingface/hub/models--TheBloke--Yi-34B-Chat-GGUF/snapshots/ee827f906e733381ab65c650dcfdd2caf6de8762/yi-34b-chat.Q4_K_M.gguf'

llm = Llama(
    model_path=Yi_34B_Chat_GGUF,
    n_gpu_layers=1,
    n_batch=512,
    f16_kv=True,  # MUST set to True, otherwise you will run into problem after a couple of calls
    chat_format="chatml",
    # callback_manager=callback_manager,
    echo=True,
    verbose=True,  # Verbose is required to pass to the callback manager
)

llm.tokenizer().encode

while True:
    in_txt = input(">>> ")
    print("<<< ", end="", flush=True)
    rep = llm.create_chat_completion(
        messages=[
            {"role": "user", "content": in_txt},
        ],
        stream=True,
        # stop=["<|im_end|>"],
        max_tokens=8192,
    )
    for chunk in rep:
        msg = chunk["choices"][0]["delta"].get("content", "")
        print(msg, end="", flush=True)
    print()
# Out:
# llama_model_loader: loaded meta data with 23 key-value pairs and 543 tensors from /Users/gensliu/.cache/huggingface/hub/models--TheBloke--Yi-34B-Chat-GGUF/snapshots/ee827f906e733381ab65c650dcfdd2caf6de8762/yi-34b-chat.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q4_K     [  7168, 64000,     1,     1 ]
# llama_model_loader: - tensor    1:           blk.0.attn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor    2:            blk.0.ffn_down.weight q6_K     [ 20480,  7168,     1,     1 ]
# llama_model_loader: - tensor    3:            blk.0.ffn_gate.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor    4:              blk.0.ffn_up.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor    5:            blk.0.ffn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor    6:              blk.0.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor    7:         blk.0.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor    8:              blk.0.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor    9:              blk.0.attn_v.weight q6_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   10:           blk.1.attn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   11:            blk.1.ffn_down.weight q6_K     [ 20480,  7168,     1,     1 ]
# llama_model_loader: - tensor   12:            blk.1.ffn_gate.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   13:              blk.1.ffn_up.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   14:            blk.1.ffn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   15:              blk.1.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   16:         blk.1.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   17:              blk.1.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   18:              blk.1.attn_v.weight q6_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   19:           blk.2.attn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   20:            blk.2.ffn_down.weight q6_K     [ 20480,  7168,     1,     1 ]
# llama_model_loader: - tensor   21:            blk.2.ffn_gate.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   22:              blk.2.ffn_up.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   23:            blk.2.ffn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   24:              blk.2.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   25:         blk.2.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   26:              blk.2.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   27:              blk.2.attn_v.weight q6_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   28:            blk.3.ffn_gate.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   29:              blk.3.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   30:         blk.3.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   31:              blk.3.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   32:              blk.3.attn_v.weight q6_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   33:           blk.3.attn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   34:            blk.3.ffn_down.weight q6_K     [ 20480,  7168,     1,     1 ]
# llama_model_loader: - tensor   35:              blk.3.ffn_up.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   36:            blk.3.ffn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   37:           blk.4.attn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   38:            blk.4.ffn_down.weight q6_K     [ 20480,  7168,     1,     1 ]
# llama_model_loader: - tensor   39:            blk.4.ffn_gate.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   40:              blk.4.ffn_up.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   41:            blk.4.ffn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   42:              blk.4.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   43:         blk.4.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   44:              blk.4.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   45:              blk.4.attn_v.weight q6_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   46:           blk.5.attn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   47:            blk.5.ffn_down.weight q6_K     [ 20480,  7168,     1,     1 ]
# llama_model_loader: - tensor   48:            blk.5.ffn_gate.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   49:              blk.5.ffn_up.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   50:            blk.5.ffn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   51:              blk.5.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   52:         blk.5.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   53:              blk.5.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   54:              blk.5.attn_v.weight q6_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   55:           blk.6.attn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   56:            blk.6.ffn_down.weight q6_K     [ 20480,  7168,     1,     1 ]
# llama_model_loader: - tensor   57:            blk.6.ffn_gate.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   58:              blk.6.ffn_up.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   59:            blk.6.ffn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor   60:              blk.6.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   61:         blk.6.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   62:              blk.6.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   63:              blk.6.attn_v.weight q6_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   64:            blk.7.ffn_gate.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   65:              blk.7.ffn_up.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor   66:              blk.7.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor   67:         blk.7.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   68:              blk.7.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor   69:              blk.7.attn_v.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor
ffn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor  519:             blk.57.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor  520:        blk.57.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor  521:             blk.57.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor  522:             blk.57.attn_v.weight q6_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor  523:          blk.58.attn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor  524:           blk.58.ffn_down.weight q6_K     [ 20480,  7168,     1,     1 ]
# llama_model_loader: - tensor  525:           blk.58.ffn_gate.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor  526:             blk.58.ffn_up.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor  527:           blk.58.ffn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor  528:             blk.58.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor  529:        blk.58.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor  530:             blk.58.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor  531:             blk.58.attn_v.weight q6_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor  532:           blk.59.ffn_gate.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor  533:             blk.59.ffn_up.weight q4_K     [  7168, 20480,     1,     1 ]
# llama_model_loader: - tensor  534:             blk.59.attn_k.weight q4_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor  535:        blk.59.attn_output.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor  536:             blk.59.attn_q.weight q4_K     [  7168,  7168,     1,     1 ]
# llama_model_loader: - tensor  537:             blk.59.attn_v.weight q6_K     [  7168,  1024,     1,     1 ]
# llama_model_loader: - tensor  538:                    output.weight q6_K     [  7168, 64000,     1,     1 ]
# llama_model_loader: - tensor  539:          blk.59.attn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor  540:           blk.59.ffn_down.weight q6_K     [ 20480,  7168,     1,     1 ]
# llama_model_loader: - tensor  541:           blk.59.ffn_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: - tensor  542:               output_norm.weight f32      [  7168,     1,     1,     1 ]
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = LLaMA v2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 4096
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 7168
# llama_model_loader: - kv   4:                          llama.block_count u32              = 60
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 20480
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 56
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32              = 5000000.000000
# llama_model_loader: - kv  11:                          general.file_type u32              = 15
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr[str,64000]   = ["<unk>", "<|startoftext|>", "<|endof...
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr[f32,64000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr[i32,64000]   = [2, 3, 3, 3, 3, 3, 1, 1, 1, 3, 3, 3, ...
# llama_model_loader: - kv  16:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  17:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  18:            tokenizer.ggml.padding_token_id u32              = 0
# llama_model_loader: - kv  19:               tokenizer.ggml.add_bos_token bool             = false
# llama_model_loader: - kv  20:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  21:                    tokenizer.chat_template str              = {% if not add_generation_prompt is de...
# llama_model_loader: - kv  22:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:  121 tensors
# llama_model_loader: - type q4_K:  361 tensors
# llama_model_loader: - type q6_K:   61 tensors
# llm_load_vocab: mismatch in special tokens definition ( 498/64000 vs 267/64000 ).
# llm_load_print_meta: format           = GGUF V3 (latest)
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 64000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 7168
# llm_load_print_meta: n_head           = 56
# llm_load_print_meta: n_head_kv        = 8
# llm_load_print_meta: n_layer          = 60
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_gqa            = 7
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: n_ff             = 20480
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 5000000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 4096
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: model type       = 30B
# llm_load_print_meta: model ftype      = mostly Q4_K - Medium
# llm_load_print_meta: model params     = 34.39 B
# llm_load_print_meta: model size       = 19.24 GiB (4.81 BPW)
# llm_load_print_meta: general.name     = LLaMA v2
# llm_load_print_meta: BOS token        = 1 '<|startoftext|>'
# llm_load_print_meta: EOS token        = 2 '<|endoftext|>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: PAD token        = 0 '<unk>'
# llm_load_print_meta: LF token         = 315 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.20 MiB
# llm_load_tensors: mem required  = 19700.44 MiB
# ...................................................................................................
# llama_new_context_with_model: n_ctx      = 512
# llama_new_context_with_model: freq_base  = 5000000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: KV self size  =  120.00 MiB, K (f16):   60.00 MiB, V (f16):   60.00 MiB
# llama_build_graph: non-view tensors processed: 1264/1264
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M2 Max
# ggml_metal_init: picking default device: Apple M2 Max
# ggml_metal_init: default.metallib not found, loading from source
# ggml_metal_init: GGML_METAL_PATH_RESOURCES = nil
# ggml_metal_init: loading '/opt/homebrew/anaconda3/envs/giftia/lib/python3.10/site-packages/llama_cpp/ggml-metal.metal'
# ggml_metal_init: GPU name:   Apple M2 Max
# ggml_metal_init: GPU family: MTLGPUFamilyApple8 (1008)
# ggml_metal_init: hasUnifiedMemory              = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 22906.50 MB
# ggml_metal_init: maxTransferRate               = built-in GPU
# llama_new_context_with_model: compute buffer total size = 142.07 MiB
# llama_new_context_with_model: max tensor size =   358.89 MiB
# ggml_metal_add_buffer: allocated 'data            ' buffer, size = 16384.00 MiB, offs =            0
# ggml_metal_add_buffer: allocated 'data            ' buffer, size =  3676.59 MiB, offs =  16803528704, (40380.88 / 21845.34)ggml_metal_add_buffer: warning: current allocated size is greater than the recommended max working set size
# ggml_metal_add_buffer: allocated 'kv              ' buffer, size =   120.05 MiB, (40500.92 / 21845.34)ggml_metal_add_buffer: warning: current allocated size is greater than the recommended max working set size
# ggml_metal_add_buffer: allocated 'alloc           ' buffer, size =   139.02 MiB, (40639.94 / 21845.34)ggml_metal_add_buffer: warning: current allocated size is greater than the recommended max working set size
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | SSSE3 = 0 | VSX = 0 |
# <<< "烟的尽头终是灰，人的尽头终是悲"这句话表达了一种对生命和存在的悲观看法。它通过比喻烟草燃烧后最终会化为灰烬，来类比人类的命运，即无论人生旅途多么辉煌灿烂，最终都会走向死亡和消逝，就像烟雾一样归于无形。
#
# 从哲学角度来看，这句话反映了存在主义的一个观点，即生命的本质是荒谬的，因为所有的生命最终都会结束，而死亡是不可避免的终点。这种观念强调了生命的有限性和脆弱性，以及人类在面对这一事实时的无力感。
#
# 然而，对于这个观点，也有人持不同意见。一些人认为，虽然死亡是每个人的最终归宿，但生命的价值和意义并不在于它的长度或结局，而是取决于我们如何生活、如何与他人建立联系以及在世界上留下怎样的印记。因此，尽管"烟的尽头终是灰，人的尽头终是悲"这句话可能让人感到沮丧，但它也可以激励人们珍惜生命中的每一刻，追求有意义的生活，并在面对死亡时保持一种更加积极和乐观的态度。
# llama_print_timings:        load time =   29880.92 ms
# llama_print_timings:      sample time =      39.23 ms /   222 runs   (    0.18 ms per token,  5658.21 tokens per second)
# llama_print_timings: prompt eval time =   29880.55 ms /    33 tokens (  905.47 ms per token,     1.10 tokens per second)
# llama_print_timings:        eval time =   15512.82 ms /   221 runs   (   70.19 ms per token,    14.25 tokens per second)
# llama_print_timings:       total time =   46440.67 ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/gensliu/giftia.proj/notebook/llamacpp.ipynb 单元格 2 line 1
#       <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> llm = Llama(
#       <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>     model_path=Yi_34B_Chat_GGUF,
#       <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>     n_gpu_layers=1,
#    (...)
#      <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a>     verbose=True,  # Verbose is required to pass to the callback manager
#      <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> )
#      <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a> while True:
# ---> <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=16'>17</a>     in_txt = input(">>> ")
#      <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a>     print("<<< ", end="", flush=True)
#      <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=18'>19</a>     rep = llm.create_chat_completion(
#      <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=19'>20</a>         messages=[
#      <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=20'>21</a>             {"role": "user", "content": in_txt},
#    (...)
#      <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=24'>25</a>         max_tokens=8192,
#      <a href='vscode-notebook-cell:/Users/gensliu/giftia.proj/notebook/llamacpp.ipynb#W1sZmlsZQ%3D%3D?line=25'>26</a>     )
#
# File /opt/homebrew/anaconda3/envs/giftia/lib/python3.10/site-packages/ipykernel/kernelbase.py:1251, in Kernel.raw_input(self, prompt)
#    1249     msg = "raw_input was called, but this frontend does not support input requests."
#    1250     raise StdinNotImplementedError(msg)
# -> 1251 return self._input_request(
#    1252     str(prompt),
#    1253     self._parent_ident["shell"],
#    1254     self.get_parent("shell"),
#    1255     password=False,
#    1256 )
#
# File /opt/homebrew/anaconda3/envs/giftia/lib/python3.10/site-packages/ipykernel/kernelbase.py:1295, in Kernel._input_request(self, prompt, ident, parent, password)
#    1292 except KeyboardInterrupt:
#    1293     # re-raise KeyboardInterrupt, to truncate traceback
#    1294     msg = "Interrupted by user"
# -> 1295     raise KeyboardInterrupt(msg) from None
#    1296 except Exception:
#    1297     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ```yaml
#
# llm:
#     yichat:
#         type: llama
#         path: /llama/yichat
#         advance:
#             verbose: true
#
# embedding:
#     luotuo:
#         type: luotuo-embeding
#
# mem:
#     chroma:
#         type: chroma
#         path: /memcached/chroma
#     history:
#         type: memcached
#         path: /memcached/history
#
# giftia:
#     llm: yichat
#     embedding: embedding
#     mem: mem
#
# ```
